# %% [markdown]
# # Classification Maps

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import xarray as xr
import xoak
from svrimg.utils.get_tables import get_table
from svrimg.utils.get_images import get_img_list
import cartopy
import cartopy.crs as ccrs

# %%
#open dummy xarray dataset
ds = xr.open_dataset('/home/scratch/WRF_BCC/severe_weather/UP_HELI_MAX/historical/1990-1991/UP_HELI_MAX_historical-1990-1991_1990-10-01.nc').sel(Time='1990-10-01T00:00:00.000000000')
ds_copy = ds.copy()

#load the geog file produce for WRF-BCC
geog = xr.open_dataset("/home/scratch/WRF_BCC/geography/geo_em.d01.nc")

#merge the datasets
ds_geog = xr.merge([ds, geog.squeeze()])
ds_geog = ds_geog.rename({"CLONG": 'lon', 'CLAT': 'lat'})

#assign lat/lon values of coarsen data and set index
ds_geog = ds_geog.assign_coords({'x': ds_geog.west_east, 'y': ds_geog.south_north})
ds_geog = ds_geog.assign_coords({'lon': ds_geog.lon, 'lat': ds_geog.lat})
ds_geog.xoak.set_index(['lat', 'lon'], 'sklearn_geo_balltree')

# %%
#load the classification labels
df = pd.read_csv('/home/jcorner1/SVRIMG/data/tor/classifications_101623.csv')
df
# Out:
#                         UNID  Class Code     Class Name
# 0     199601030010z000000859           0  isolated_cell
# 1     199601030020z000000860           0  isolated_cell
# 2     199605022300z000000295           0  isolated_cell
# 3     199605150140z000000715           0  isolated_cell
# 4     199605160408z000000190           0  isolated_cell
# ...                      ...         ...            ...
# 5784  201710082137z000615804           5       tropical
# 5785  201710082140z000615805           5       tropical
# 5786  201710082151z000615806           5       tropical
# 5787  201710082201z000615807           5       tropical
# 5788  201710082245z000615808           5       tropical
#
# [5789 rows x 3 columns]

# %%
#download tables and images from SVRIMG
df_not_subset = get_table(which='svrimg', haz_type='tor', data_dir="/home/jcorner1/SVRIMG/data/CSVs")
df_not_subset.ymin
# Out:
# unid
# 199601011725z000000001    112
# 199601030010z000000859    270
# 199601030020z000000860    270
# 199601031307z000000004     41
# 199601031340z000000005     52
#                          ...
# 201712200759z000615894    141
# 201712200817z000615895    143
# 201712201239z000615896    174
# 201712201640z000615897    242
# 201712201815z000615898    241
# Name: ymin, Length: 27052, dtype: int64

# %%
#join the SVRIMG csv with the classification csv
df = df.set_index(df["UNID"])
df
# Out:
#                                           UNID  Class Code     Class Name
# UNID
# 199601030010z000000859  199601030010z000000859           0  isolated_cell
# 199601030020z000000860  199601030020z000000860           0  isolated_cell
# 199605022300z000000295  199605022300z000000295           0  isolated_cell
# 199605150140z000000715  199605150140z000000715           0  isolated_cell
# 199605160408z000000190  199605160408z000000190           0  isolated_cell
# ...                                        ...         ...            ...
# 201710082137z000615804  201710082137z000615804           5       tropical
# 201710082140z000615805  201710082140z000615805           5       tropical
# 201710082151z000615806  201710082151z000615806           5       tropical
# 201710082201z000615807  201710082201z000615807           5       tropical
# 201710082245z000615808  201710082245z000615808           5       tropical
#
# [5789 rows x 3 columns]

# %%
df_join = df.join(df_not_subset)
df_join
# Out:
#                                           UNID  Class Code     Class Name  \
# UNID
# 199601030010z000000859  199601030010z000000859           0  isolated_cell
# 199601030020z000000860  199601030020z000000860           0  isolated_cell
# 199605022300z000000295  199605022300z000000295           0  isolated_cell
# 199605150140z000000715  199605150140z000000715           0  isolated_cell
# 199605160408z000000190  199605160408z000000190           0  isolated_cell
# ...                                        ...         ...            ...
# 201710082137z000615804  201710082137z000615804           5       tropical
# 201710082140z000615805  201710082140z000615805           5       tropical
# 201710082151z000615806  201710082151z000615806           5       tropical
# 201710082201z000615807  201710082201z000615807           5       tropical
# 201710082245z000615808  201710082245z000615808           5       tropical
#
#                                area  convection_area  \
# UNID
# 199601030010z000000859   12150.0000         998.4375
# 199601030020z000000860   12079.6875         998.4375
# 199605022300z000000295   26606.2500         168.7500
# 199605150140z000000715   11137.5000         506.2500
# 199605160408z000000190   19673.4375        1603.1250
# ...                             ...              ...
# 201710082137z000615804  116634.3750        2812.5000
# 201710082140z000615805  117028.1250        2798.4375
# 201710082151z000615806  114848.4375        2840.6250
# 201710082201z000615807  115762.5000        2840.6250
# 201710082245z000615808  124776.5625        4331.2500
#
#                                                                  filename  \
# UNID
# 199601030010z000000859  /data/haberlie/report_boxes_gridrad/tor/1996/0...
# 199601030020z000000860  /data/haberlie/report_boxes_gridrad/tor/1996/0...
# 199605022300z000000295  /data/haberlie/report_boxes_gridrad/tor/1996/0...
# 199605150140z000000715  /data/haberlie/report_boxes_gridrad/tor/1996/0...
# 199605160408z000000190  /data/haberlie/report_boxes_gridrad/tor/1996/0...
# ...                                                                   ...
# 201710082137z000615804  /data/haberlie/report_boxes_gridrad/tor/2017/1...
# 201710082140z000615805  /data/haberlie/report_boxes_gridrad/tor/2017/1...
# 201710082151z000615806  /data/haberlie/report_boxes_gridrad/tor/2017/1...
# 201710082201z000615807  /data/haberlie/report_boxes_gridrad/tor/2017/1...
# 201710082245z000615808  /data/haberlie/report_boxes_gridrad/tor/2017/1...
#
#                         intense_area  intensity_variance kind  max_intensity  \
# UNID
# 199601030010z000000859      182.8125          120.341792  tor             60
# 199601030020z000000860      182.8125          120.944422  tor             60
# 199605022300z000000295       28.1250          102.806528  tor             54
# 199605150140z000000715       84.3750           58.449095  tor             52
# 199605160408z000000190      660.9375           70.396541  tor             65
# ...                              ...                 ...  ...            ...
# 201710082137z000615804        0.0000           98.966033  tor             49
# 201710082140z000615805        0.0000           98.147275  tor             49
# 201710082151z000615806        0.0000           95.196858  tor             49
# 201710082201z000615807        0.0000           95.085247  tor             49
# 201710082245z000615808        0.0000          103.568503  tor             49
#
#                         mean_intensity  \
# UNID
# 199601030010z000000859        2.448692
# 199601030020z000000860        2.425011
# 199605022300z000000295        4.554715
# 199605150140z000000715        3.661711
# 199605160408z000000190        5.541414
# ...                                ...
# 201710082137z000615804       16.884299
# 201710082140z000615805       16.938203
# 201710082151z000615806       16.352076
# 201710082201z000615807       16.415603
# 201710082245z000615808       17.528871
#
#                                                                radar_file  \
# UNID
# 199601030010z000000859  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/1...
# 199601030020z000000860  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/1...
# 199605022300z000000295  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/1...
# 199605150140z000000715  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/1...
# 199605160408z000000190  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/1...
# ...                                                                   ...
# 201710082137z000615804  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/2...
# 201710082140z000615805  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/2...
# 201710082151z000615806  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/2...
# 201710082201z000615807  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/2...
# 201710082245z000615808  /data/haberlie/sim_4k_interp/GRIDRAD_MAXREFC/2...
#
#                              radar_time      report_time  xmax  xmin  ymax  \
# UNID
# 199601030010z000000859    1/3/1996 0:00    1/3/1996 0:10  1176  1041   405
# 199601030020z000000860    1/3/1996 0:00    1/3/1996 0:20  1177  1042   405
# 199605022300z000000295   5/2/1996 23:00   5/2/1996 23:00   791   656   670
# 199605150140z000000715   5/15/1996 2:00   5/15/1996 1:40   721   586   407
# 199605160408z000000190   5/16/1996 4:00   5/16/1996 4:08   673   538   619
# ...                                 ...              ...   ...   ...   ...
# 201710082137z000615804  10/8/2017 22:00  10/8/2017 21:37  1135  1000   448
# 201710082140z000615805  10/8/2017 22:00  10/8/2017 21:40  1135  1000   449
# 201710082151z000615806  10/8/2017 22:00  10/8/2017 21:51  1149  1014   469
# 201710082201z000615807  10/8/2017 22:00  10/8/2017 22:01  1149  1014   471
# 201710082245z000615808  10/8/2017 23:00  10/8/2017 22:45  1149  1014   481
#
#                         ymin
# UNID
# 199601030010z000000859   270
# 199601030020z000000860   270
# 199605022300z000000295   535
# 199605150140z000000715   272
# 199605160408z000000190   484
# ...                      ...
# 201710082137z000615804   313
# 201710082140z000615805   314
# 201710082151z000615806   334
# 201710082201z000615807   336
# 201710082245z000615808   346
#
# [5789 rows x 18 columns]

# %%
df_join['x_cent'] = ((df_join['xmax'] + df_join['xmin']+1)/2).astype(int)
df_join['y_cent'] = ((df_join['ymax'] + df_join['ymin'])/2).astype(int)

# %%
#create an array of zeros
zeros = np.zeros((ds_geog.lat.values.shape))

for rid, row in df_join.iterrows():
    zeros[row.y_cent, row.x_cent] = zeros[row.y_cent, row.x_cent] + 1
    
ds_mode = ds_geog.assign(UP_HELI_MAX = (('south_north', 'west_east'), zeros))
geog_cor = geog[['CLAT', 'CLONG']].coarsen(south_north=20, west_east=20, boundary='trim').mean()

ds_mode = ds_mode.coarsen(south_north=20, west_east=20, boundary='trim').sum()
ds_mode = xr.merge([ds_mode, geog_cor.squeeze()])

# %%
ax = plt.subplot(1,1,1, projection=ccrs.LambertConformal(central_longitude=-98, central_latitude=35))

data = ds_mode.UP_HELI_MAX.values
data[data==0] = np.nan

c = ax.pcolormesh(ds_mode.lon.values, ds_mode.lat.values, ds_mode.UP_HELI_MAX.values, transform=cartopy.crs.PlateCarree(), cmap='YlOrBr')

ax.add_feature(cartopy.feature.STATES, zorder=2)
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.LAND, facecolor='white')
ax.add_feature(cartopy.feature.OCEAN, facecolor='lightblue', zorder=2)
ax.add_feature(cartopy.feature.LAKES, facecolor='lightblue')

ax.set_extent([-120, -74, 20, 50])


cbar = plt.colorbar(c, shrink=0.5, pad=0.01, extend='both', ticks=list(range(0, 60, 10)), ax=ax)
cbar.ax.tick_params(labelsize=10)
cbar.set_label(label='Frequency', size=10)
