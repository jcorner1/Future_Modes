# %% [markdown]
# # Create CNN Model
# This notebook is a combination of works with the first being the https://www.tensorflow.org/tutorials/load_data/images and the next being the SVRIMG https://github.com/ahaberlie/SVRIMG/blob/master/examples/Train_Model.ipynb

# %%
import pandas as pd
import numpy as np
import glob
import PIL

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %% [markdown]
# ## Obtain Data

# %%
results = pd.read_csv('/home/jovyan/Thesis/data/classifications_spc_actual_tornadoes.csv')
results
# Out:
#                         UNID  Class Code     Class Name      om  tz  st  stf  \
# 0     199601030010z000000859           0  isolated_cell     859   3  SC   45
# 1     199601030020z000000860           0  isolated_cell     860   3  SC   45
# 2     199605022300z000000295           0  isolated_cell     295   3  MN   27
# 3     199605150140z000000715           0  isolated_cell     715   3  OK   40
# 4     199605160408z000000190           0  isolated_cell     190   3  NE   31
# ...                      ...         ...            ...     ...  ..  ..  ...
# 5784  201710082137z000615804           5       tropical  615804   3  SC   45
# 5785  201710082140z000615805           5       tropical  615805   3  NC   37
# 5786  201710082151z000615806           5       tropical  615806   3  NC   37
# 5787  201710082201z000615807           5       tropical  615807   3  NC   37
# 5788  201710082245z000615808           5       tropical  615808   3  NC   37
#
#       stn  mag  inj  ...  f3  f4  fc            init_date         fmt_date  \
# 0       1    0    0  ...   0   0   0  1996-01-02-18:10:00   1/2/1996 18:10
# 1       2    0    0  ...   0   0   0  1996-01-02-18:20:00   1/2/1996 18:20
# 2       1    0    0  ...   0   0   0  1996-05-02-17:00:00   5/2/1996 17:00
# 3      20    0    0  ...   0   0   0  1996-05-14-19:40:00  5/14/1996 19:40
# 4       6    0    0  ...   0   0   0  1996-05-15-22:08:00  5/15/1996 22:08
# ...   ...  ...  ...  ...  ..  ..  ..                  ...              ...
# 5784    0    1    0  ...   0   0   0  2017-10-08-15:37:00  10/8/2017 15:37
# 5785    0    1    0  ...   0   0   0  2017-10-08-15:40:00  10/8/2017 15:40
# 5786    0    0    0  ...   0   0   0  2017-10-08-15:51:00  10/8/2017 15:51
# 5787    0    1    0  ...   0   0   0  2017-10-08-16:01:00  10/8/2017 16:01
# 5788    0    1    0  ...   0   0   0  2017-10-08-16:45:00  10/8/2017 16:45
#
#              date_utc    yr  mo  dy  hr
# 0       1/3/1996 0:10  1996   1   3   0
# 1       1/3/1996 0:20  1996   1   3   0
# 2      5/2/1996 23:00  1996   5   2  23
# 3      5/15/1996 1:40  1996   5  15   1
# 4      5/16/1996 4:08  1996   5  16   4
# ...               ...   ...  ..  ..  ..
# 5784  10/8/2017 21:37  2017  10   8  21
# 5785  10/8/2017 21:40  2017  10   8  21
# 5786  10/8/2017 21:51  2017  10   8  21
# 5787  10/8/2017 22:01  2017  10   8  22
# 5788  10/8/2017 22:45  2017  10   8  22
#
# [5789 rows x 34 columns]

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  f'/home/jovyan/Thesis/data/',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(136, 136),
  batch_size=57)
# Out:
# Found 5789 files belonging to 7 classes.
# Using 4632 files for training.
# 2023-06-26 22:04:09.303751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.318485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.318667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.319755: I tensorflow/core/platform/cpu_feature_guard.cc:152] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 22:04:09.320218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.320373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.320501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.930664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.930882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.931024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:952] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-26 22:04:09.931152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6969 MB memory:  -> device: 0, name: GRID A100X-10C, pci bus id: 0000:04:00.0, compute capability: 8.0

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  f'/home/jovyan/Thesis/data/',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(136, 136),
  batch_size=57)
# Out:
# Found 5789 files belonging to 7 classes.
# Using 1157 files for validation.

# %%
class_names = train_ds.class_names
class_names[1:]
# Out:
# ['isolated_cell',
#  'loosely_clustered_cells',
#  'multiple_isolated_cells',
#  'qlcs',
#  'tightly_clustered_cells',
#  'tropical']

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (57, 136, 136, 3)
# (57,)

# %% [markdown]
# ## Create the Model

# %%
#Check for GPU access
gpus = tf.config.experimental.list_physical_devices(device_type="GPU")
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(136, 136, 3)),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.SpatialDropout2D(0.3),
        layers.MaxPooling2D(pool_size=(3, 3)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.SpatialDropout2D(0.3),
        layers.MaxPooling2D(pool_size=(3, 3)),
        layers.Conv2D(128, kernel_size=(3, 3), activation="relu"),
        layers.SpatialDropout2D(0.3),
        layers.MaxPooling2D(pool_size=(3, 3)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.6),
        #layers.Dense(6, activation="sigmoid"),
        layers.Dense(6, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 134, 134, 32)      896
#
#  spatial_dropout2d_12 (Spati  (None, 134, 134, 32)     0
#  alDropout2D)
#
#  max_pooling2d_21 (MaxPoolin  (None, 44, 44, 32)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 42, 42, 64)        18496
#
#  spatial_dropout2d_13 (Spati  (None, 42, 42, 64)       0
#  alDropout2D)
#
#  max_pooling2d_22 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 128)       73856
#
#  spatial_dropout2d_14 (Spati  (None, 12, 12, 128)      0
#  alDropout2D)
#
#  max_pooling2d_23 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 2048)              0
#
#  dense_13 (Dense)            (None, 128)               262272
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 356,294
# Trainable params: 356,294
# Non-trainable params: 0
# _________________________________________________________________

# %%
object = PIL.Image.open(f'/home/jovyan/Thesis/data/isolated_cell/199601030010z000000859.png')
object
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=222x212>

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
epochs = 100
#model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])


#model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  workers=8
)
# Out:
# Epoch 1/100
# 82/82 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0017 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 2/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 3/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 4/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 5/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 6/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 7/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 8/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 9/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 10/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 11/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 12/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 13/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 14/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 15/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 16/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 17/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 18/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 19/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 20/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 21/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 22/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 23/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 24/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 25/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 26/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 27/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 28/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 29/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 30/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 31/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 32/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 33/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 34/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 35/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 36/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 37/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 38/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 39/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 40/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 41/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 42/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 43/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 44/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 45/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 46/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 47/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 48/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 49/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 50/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 51/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 52/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 53/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 54/100
# 82/82 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 55/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 56/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 57/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 58/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 59/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 60/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 61/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 62/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 63/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 64/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 65/100
# 82/82 [==============================] - 1s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 66/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 67/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 68/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 69/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 70/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 71/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 72/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 73/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 74/100
# 82/82 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 75/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 76/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 77/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 78/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 79/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 80/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 81/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 82/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 83/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 84/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 85/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 86/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 87/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 88/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 89/100
# 82/82 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 90/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 91/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 92/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 93/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 94/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 95/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 96/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 97/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 98/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 99/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 100/100
# 82/82 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
