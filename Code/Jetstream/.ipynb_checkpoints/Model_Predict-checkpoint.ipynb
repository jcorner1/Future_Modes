# %% [markdown]
# # Model Classification of Convective Mode

# %%
import numpy as np
import pandas as pd
import glob

import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2024-04-25 22:47:35.873592: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 22:47:35.873672: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 22:47:35.873727: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-25 22:47:35.884860: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load CSV and Model

# %%
#load the csvs
epoch = 'END8p5'
year = 2086

df = pd.concat(map(pd.read_csv, glob.glob(f'/share/jcorner_data/csvs/{epoch}/*{year}*')), ignore_index=True)
df
# Out:
#        Unnamed: 0    x    y                Filename  \
# 0               0  777  363    07012086_T00_0id.npy
# 1               1  778  363    07012086_T00_1id.npy
# 2               2  779  363    07012086_T00_2id.npy
# 3               3  781  369    07012086_T00_3id.npy
# 4               4  782  369    07012086_T00_4id.npy
# ...           ...  ...  ...                     ...
# 17579         175  783  677  09242086_T21_175id.npy
# 17580         176  803  679  09242086_T22_176id.npy
# 17581         177  793  713  09242086_T22_177id.npy
# 17582         178  825  720  09242086_T23_178id.npy
# 17583         179  824  729  09242086_T23_179id.npy
#
#                                 Time
# 0      2086-07-01T00:00:00.000000000
# 1      2086-07-01T00:00:00.000000000
# 2      2086-07-01T00:00:00.000000000
# 3      2086-07-01T00:00:00.000000000
# 4      2086-07-01T00:00:00.000000000
# ...                              ...
# 17579  2086-09-24T21:00:00.000000000
# 17580  2086-09-24T22:00:00.000000000
# 17581  2086-09-24T22:00:00.000000000
# 17582  2086-09-24T23:00:00.000000000
# 17583  2086-09-24T23:00:00.000000000
#
# [17584 rows x 5 columns]

# %%
#load the CNN model
model = keras.models.load_model('/share/jcorner_data/models/future_modes_v2.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 12)      984
#
#  conv2d_1 (Conv2D)           (None, 120, 120, 24)      23352
#
#  average_pooling2d (Average  (None, 24, 24, 24)        0
#  Pooling2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 48)        93360
#
#  average_pooling2d_1 (Avera  (None, 3, 3, 48)          0
#  gePooling2D)
#
#  flatten (Flatten)           (None, 432)               0
#
#  dense (Dense)               (None, 4)                 1732
#
# =================================================================
# Total params: 119428 (466.52 KB)
# Trainable params: 119428 (466.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2024-04-25 22:47:38.533084: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.561930: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.562072: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.563203: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.563336: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.563445: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.721582: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.721742: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.721873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-25 22:47:38.721958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7107 MB memory:  -> device: 0, name: GRID A100X-10C, pci bus id: 0000:04:00.0, compute capability: 8.0

# %% [markdown]
# ## Classify Convective Mode

# %%
#create a list with the number corresponding to the convective mode.
lookup = {0:'Cellular', 1:'Multicell', 
          2:'Linear', 3:'Other'}

#create the new dataframe with the mode column
new_df = pd.DataFrame(columns=['x', 'y', 'Filename', 'Time', 'Mode'])
modes = []
xs = []
ys = []
filenames = []
times = []

#iterate through all the numpy files in the directory
for rid, row in df[:10000].iterrows():
    
    #isolate the filename from the path and dataframe
    path = f'/share/jcorner_data/storm_images/{epoch}/{row.Filename}'

    #load the file
    file = np.load(path)

    if file.shape == (136, 136):
        
        #normalize the data
        file = file/80
    
        #expand the dimensions to the correct size
        file = np.expand_dims(file, 2)
        file = np.expand_dims(file, 0)
    
        #classify the convective mode using the CNN
        pred = model.predict(file, verbose=None)
        mode = [lookup[x] for x in np.argmax(pred, axis=1)]

        #append values to list
        modes.append(mode[0])
        filenames.append(row.Filename)
        xs.append(row.x)
        ys.append(row.y)
        times.append(row.Time)
        
#apply to dataframe
new_df['Mode'] = modes
new_df['Filename'] = filenames
new_df['x'] = xs
new_df['y'] = ys
new_df['Time'] = times
new_df
# Out:
# 2024-04-25 22:47:39.126141: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
#          x    y                Filename                           Time  \
# 0      777  363    07012086_T00_0id.npy  2086-07-01T00:00:00.000000000
# 1      778  363    07012086_T00_1id.npy  2086-07-01T00:00:00.000000000
# 2      779  363    07012086_T00_2id.npy  2086-07-01T00:00:00.000000000
# 3      781  369    07012086_T00_3id.npy  2086-07-01T00:00:00.000000000
# 4      782  369    07012086_T00_4id.npy  2086-07-01T00:00:00.000000000
# ...    ...  ...                     ...                            ...
# 9995  1172  386  06062086_T20_794id.npy  2086-06-06T20:00:00.000000000
# 9996  1173  386  06062086_T20_795id.npy  2086-06-06T20:00:00.000000000
# 9997  1172  387  06062086_T20_796id.npy  2086-06-06T20:00:00.000000000
# 9998  1173  387  06062086_T20_797id.npy  2086-06-06T20:00:00.000000000
# 9999   960  465  06062086_T20_798id.npy  2086-06-06T20:00:00.000000000
#
#            Mode
# 0     Multicell
# 1     Multicell
# 2     Multicell
# 3     Multicell
# 4     Multicell
# ...         ...
# 9995   Cellular
# 9996   Cellular
# 9997   Cellular
# 9998   Cellular
# 9999  Multicell
#
# [10000 rows x 5 columns]

# %%
#save the dataframe to a csv
new_df.to_csv(f'/share/jcorner_data/csvs/modes/{epoch}/storm_modes_{year}_1_{epoch}.csv')

# %% [markdown]
# ## Check Model Predictions

# %%
#create a histogram from the predictions
plt.rcParams['figure.figsize'] = 17, 10
new_df.Mode.hist(xlabelsize = 12)
# Out:
# <Axes: >

# %%
from svrimg.mapping.map_helper import radar_colormap, draw_box_plot
from matplotlib.colors import BoundaryNorm

#load a radarcolormap
cmap = radar_colormap()
classes = np.array(list(range(0, 85, 5)))
norm = BoundaryNorm(classes, ncolors=cmap.N)

#iterate through each class
for i in range(6):
    ax = plt.subplot(2,3,i+1)

    #find a random image for each class and annotate the class
    sample = np.load(f"/shared/shared/jcorner_data/eoc8p5/{new_df[(new_df['Mode'] == lookup[i])].sample()['Filename'].values[0]}")
    ax.annotate(f'{lookup[i]}', (0.03,0.05),fontsize=15, 
                        bbox=dict(boxstyle='round', facecolor='w', alpha=1), xycoords='axes fraction')

    #plot the data
    draw_box_plot(ax, sample.squeeze())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from svrimg.mapping.map_helper import radar_colormap, draw_box_plot
#       2 from matplotlib.colors import BoundaryNorm
#       4 #load a radarcolormap
#
# ModuleNotFoundError: No module named 'svrimg'
